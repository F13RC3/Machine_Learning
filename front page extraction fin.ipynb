# %%
from PIL import Image
from pytesseract import image_to_string
import pytesseract
import numpy as np
import pandas as pd
import PIL
from PIL import Image, ImageFilter, ImageEnhance
import cv2
import colorsys
import dill
# dill.dump_session('Extract.db')
dill.load_session('Extract.db')

# %% [markdown]
# **UNINSTALL AND REINSTALL**
#
# https://digi.bib.uni-mannheim.de/tesseract/tesseract-ocr-setup-3.05.02-20180621.exe
#
#
# Uninstall previously installed tesseract application and reinstall it with above link.

# %%
# pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files (x86)\Tesseract-OCR\tesseract.exe"

# %% [markdown]
# **ORIGINAL**

# %%
im = Image.open("/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P167_1.jpeg")
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1653x2339 at 0x7FB34DDD9908>

# %% [markdown]
# **Rescaling**

# %%
basewidth = 1700
wpercent = (basewidth / float(im.size[0]))
hsize = int((float(im.size[1]) * float(wpercent)))
imz = im.resize((basewidth, hsize), PIL.Image.ANTIALIAS)
imz
# Out:
# <PIL.Image.Image image mode=RGB size=1700x2405 at 0x7FB3643771D0>

# %% [markdown]
# **Making Image Binary**

# %%
im = cv2.bilateralFilter(np.array(imz,dtype=np.uint8),9,75,75)
imb = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
ims  = Image.fromarray(imb)   
ims
# Out:
# <PIL.Image.Image image mode=L size=1700x2405 at 0x7FB388082320>

# %%
im = cv2.adaptiveThreshold(np.array(ims,dtype=np.uint8), 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 31, 11)
im = Image.fromarray(im)
im
# Out:
# <PIL.Image.Image image mode=L size=1700x2405 at 0x7FB3642A0400>

# %% [markdown]
# **Things required to be extracted**
#
# 1. Vidhan Sabha name
# 2. Part No/Bhag Sankhya
# 3. Details of part and polling area/
# 4. No. and name of polling station
# 5. Male/Female/Total
# 6. File Name

# %%
crop_rectangle_vs = (716, 110, 910, 202)
cropped_im_vs = im.crop(crop_rectangle_vs)
crop_rectangle_bs = (1462, 110, 1550, 205)
cropped_im_bs = im.crop(crop_rectangle_bs)
# crop_rectangle_mg = (830, 737, 1017, 770)
# cropped_im_mg = im.crop(crop_rectangle_mg)
crop_rectangle_psn = (159, 1550, 1050, 1630)
cropped_im_psn = im.crop(crop_rectangle_psn)
crop_rectangle_psa = (170, 1670, 1125, 1725)
cropped_im_psa = im.crop(crop_rectangle_psa)
crop_rectangle_male = (820, 1965, 955, 2050)
cropped_im_male = im.crop(crop_rectangle_male)
crop_rectangle_fem = (1020, 1965, 1175, 2050)
cropped_im_fem = im.crop(crop_rectangle_fem)
crop_rectangle_tot = (1400, 1965, 1565, 2050)
cropped_im_tot = im.crop(crop_rectangle_tot)
cropped_im_vs
# Out:
# <PIL.Image.Image image mode=L size=194x92 at 0x7FCB8C3A9748>

# %%
import glob
# To input only first page of pdfs, we will input all jpgs path whose file name is ending with '-01.jpg'
onlyfiles = glob.glob('/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/*_1.jpeg')

# %%
s ='/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/*_1.jpeg'
s = s.split('/')
s[6]
# Out:
# '*_1.jpeg'

# %% [markdown]
# We require file name for every file our code reads. To read that we will input file name from the path.
# For example, when I read onlyfiles list I have created above, it shows paths such as
# 'C:/Users/SUYASH/Downloads/AC0020001\\\ **AC0020001**-01.jpg'
#
# Here we require highlighted text. To get that we will split the string with respect to '\\\'. Our O/P will be a list as follows.
#
# ['C:/Users/SUYASH/Downloads/AC0020001','**AC0020001**-01.jpg']
#
# Then we will take second part of the list('**AC0020001**-01.jpg') and split it by '-'. Our O/P will be a list as follows.
#
# ['**AC0020001**',01.jpg']
#
# Here first item of the list is our requirement.

# %%
def img_to_txt(x):
    s = x.split('/')
    s = s[6].split("_")[0]
    im = Image.open(x)
    basewidth = 1700
    wpercent = (basewidth / float(im.size[0]))
    hsize = int((float(im.size[1]) * float(wpercent)))
    im = im.resize((basewidth, hsize), PIL.Image.ANTIALIAS)
    im = cv2.bilateralFilter(np.array(im,dtype=np.uint8),9,75,75)
    im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    im = cv2.adaptiveThreshold(np.array(im,dtype=np.uint8), 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 31, 11)
    im = Image.fromarray(im)
    cropped_im_vs = im.crop(crop_rectangle_vs)
    c_vs = image_to_string(cropped_im_vs,config='-c tessedit_char_whitelist=abcdefghijklmnopqrstuvwxyzQWERTYUIOPASDFGHJKLZXCVBNM --psm 6')
    cropped_im_bs = im.crop(crop_rectangle_bs)
    c_bs = image_to_string(cropped_im_bs,config='-c tessedit_char_whitelist=0123456789 --psm 6')
#     cropped_im_mg = im.crop(crop_rectangle_mg)
#     c_mg = image_to_string(cropped_im_mg,lang = 'eng',config='-c tessedit_char_whitelist=abcdefghijklmnopqrstuvwxyz -psm 6')
    cropped_im_psn = im.crop(crop_rectangle_psn)
    c_psn = image_to_string(cropped_im_psn,config='--psm 6')
    cropped_im_psa = im.crop(crop_rectangle_psa)
    c_psa = image_to_string(cropped_im_psa,config='-c tessedit_char_whitelist=abcdefghijklmnopqrstuvwxyzQWERTYUIOPASDFGHJKLZXCVBNM --psm 6')
    cropped_im_male = im.crop(crop_rectangle_male)
    c_male = image_to_string(cropped_im_male,config='-c tessedit_char_whitelist=0123456789 --psm 6')
    cropped_im_fem = im.crop(crop_rectangle_fem)
    c_fem = image_to_string(cropped_im_fem,config='-c tessedit_char_whitelist=0123456789 --psm 6')
    cropped_im_tot = im.crop(crop_rectangle_tot)
    c_tot = image_to_string(cropped_im_tot,config='-c tessedit_char_whitelist=0123456789 --psm 6')
    return c_vs,c_bs,c_psn,c_psa,s,c_male,c_fem,c_tot

# %%
onlyfiles
# Out:
# ['/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P167_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P168_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P169_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P170_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P171_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P172_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P173_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P174_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P175_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P176_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P177_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P178_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P179_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P180_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P181_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P182_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P183_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P184_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P185_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P186_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P187_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P188_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P189_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P191_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P192_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P193_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P194_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P190_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P195_1.jpeg',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/pics_task/U05A57P196_1.jpeg']

# %%
vidhnsbha = []
bhag_snkhya = []
main_vil = []
PS_name = []
PS_add = []
file_name = []
male = []
female = []
total = []
for i in onlyfiles:
    a,b,d,e,s,m,f,o = img_to_txt(i)
    vidhnsbha.append(a)
    bhag_snkhya.append(b)
#     main_vil.append(c)
    PS_name.append(d)
    PS_add.append(e)
    file_name.append(s)
    male.append(m)
    female.append(f)
    total.append(o)
# vidhnsbha

# %%
import numpy as np
front_pange = pd.DataFrame(np.column_stack([vidhnsbha, bhag_snkhya,PS_name,PS_add,male,female,total,file_name]), 
                               columns=['vidhan_sabha', 'bhag_sankhya','PS_name','PS_add','male','female','total','file_name'])

# %%
front_pange.head(30)
# Out:
#    vidhan_sabha bhag_sankhya  \
# 0   embly Const
# 1   embly Const
# 2   embly Const
# 3   embly Const
# 4   embly Const
# 5   embly Const
# 6   embly Const
# 7   embly Const
# 8   embly Const
# 9   embly Const
# 10  embly Const
# 11  embly Const
# 12  embly Const
# 13  embly Const
# 14  embly Const
# 15  embly Const
# 16  embly Const
# 17  embly Const
# 18  embly Const
# 19  embly Const
# 20  embly Const
# 21  embly Const
# 22  embly Const
# 23  embly Const
# 24  embly Const
# 25  embly Const
# 26  embly Const
# 27  embly Const
# 28  embly Const
# 29  embly Const
#
#                                               PS_name  \
# 0                                   UMBER OF ELECTORS
# 1                                   UMBER OF ELECTORS
# 2                                   UMBER OF ELECTORS
# 3                                   UMBER OF ELECTORS
# 4                                   UMBER OF ELECTORS
# 5                                   UMBER OF ELECTORS
# 6                                   UMBER OF ELECTORS
# 7                                     PKT-IV, MAYUR l
# 8                                     PKT-IV, MAYUR l
# 9                                     PKT-IV, MAYUR l
# 10                                    PKT-IV, MAYUR l
# 11                                            MAYUR l
# 12                                            MAYUR l
# 13                                            MAYUR l
# 14                                       PATPARGANJ l
# 15                                       PATPARGANJ l
# 16                                       PATPARGANJ l
# 17                                       PATPARGANJ l
# 18                                       PATPARGANJ l
# 19                                            MAYUR l
# 20                                          PKT-lV. l
# 21                                          PKT-lV. l
# 22                                          PKT-lV. l
# 23                                          PKT-lV. l
# 24  mm.” a u UV. Mm. V. ..._._n v......-.. mm“ nun...
# 25  mm.” a u UV. Mm. V. ..._._n v......-.. mm“ nun...
# 26  mm.” a u UV. Mm. V. ..._._n v......-.. mm“ nun...
# 27                                          PKT-lV. l
# 28  mm.” a u UV. Mm. V. ..._._n v......-.. mm“ nun...
# 29  ,v, m...“ vll‘vunnvru\l m... 9.... . |\nUMBER ...
#
#                                                PS_add male  female  \
# 0                 lNoe I Serial Noe Male I Female Thi
# 1                 lNoe I Serial Noe Male I Female Thi
# 2                 lNoe I Serial Noe Male I Female Thi
# 3                 lNoe I Serial Noe Male I Female Thi
# 4                 lNoe I Serial Noe Male I Female Thi
# 5                 lNoe I Serial Noe Male I Female Thi
# 6                 lNoe I Serial Noe Male I Female Thi
# 7                                                           58 190
# 8                                                           58 190
# 9                                                           58 190
# 10                                                          58 190
# 11                                                           55 56
# 12                                                           55 56
# 13                                                           55 56
# 14                                                           55 56
# 15                                                           55 56
# 16                                                           55 56
# 17                                                           55 56
# 18                                                           55 56
# 19                                                          58 190
# 20                                                           55 56
# 21                                                           55 56
# 22                                                           55 56
# 23                                                           55 56
# 24  ms Hmmg uh mnw\nI No I Serial Noe Male I Femal...
# 25  ms Hmmg uh mnw\nI No I Serial Noe Male I Femal...
# 26  ms Hmmg uh mnw\nI No I Serial Noe Male I Femal...
# 27                                                           55 56
# 28  ms Hmmg uh mnw\nI No I Serial Noe Male I Femal...
# 29  ms Hmmg uh mnw\nI No I Serial Noe Male I Femal...
#
#              total   file_name
# 0                   U05A57P167
# 1                   U05A57P168
# 2                   U05A57P169
# 3                   U05A57P170
# 4                   U05A57P171
# 5                   U05A57P172
# 6                   U05A57P173
# 7   21 011  111  5  U05A57P174
# 8   21 011  111  5  U05A57P175
# 9   21 011  111  5  U05A57P176
# 10  21 011  111  5  U05A57P177
# 11      0 1 0  1 3  U05A57P178
# 12      0 1 0  1 3  U05A57P179
# 13      0 1 0  1 3  U05A57P180
# 14      0 1 0  1 3  U05A57P181
# 15      0 1 0  1 3  U05A57P182
# 16      0 1 0  1 3  U05A57P183
# 17      0 1 0  1 3  U05A57P184
# 18      0 1 0  1 3  U05A57P185
# 19  21 011  111  5  U05A57P186
# 20      0 1 0  1 3  U05A57P187
# 21      0 1 0  1 3  U05A57P188
# 22      0 1 0  1 3  U05A57P189
# 23      0 1 0  1 3  U05A57P191
# 24                  U05A57P192
# 25                  U05A57P193
# 26                  U05A57P194
# 27      0 1 0  1 3  U05A57P190
# 28                  U05A57P195
# 29                  U05A57P196

# %%
# front_pange.to_csv("front_page1.csv",index = False)
front_pange.to_excel("front_page1.xlsx",index = False)

# %%
# front_pange.head()

# %%
c_psn = image_to_string(cropped_im_vs,config=
                        '-c tessedit_char_whitelist=1 --psm 6')
c_psn
# Out:
# '1   111   1  1  1'
